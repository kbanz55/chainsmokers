# %% [markdown]
# <a href="https://colab.research.google.com/github/kbanz55/chainsmokers/blob/master/BloodMNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning Medical Image Analysis
# A simple convolutional neural network model trained using a simple Blood image dataset.

# %% [markdown]
# ## Python Imports
# We load the necessary python packages to the instance.

# %%
# Built-in Imports
import random

# %%
# Library Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# Keras Imports
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import get_file, to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Dataset Downloader
# download the selected [MedMNIST](https://medmnist.github.io/) dataset as a NumPy array object to your Google Colab instance.

# %%
DATA_NAME = "BloodMNIST"

# %%
# !wget https://raw.githubusercontent.com/MedMNIST/MedMNIST/main/medmnist/info.py
from info import INFO
data = INFO[DATA_NAME.lower()]
# Out:
# --2023-04-10 19:06:49--  https://raw.githubusercontent.com/MedMNIST/MedMNIST/main/medmnist/info.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22841 (22K) [text/plain]
# Saving to: ‘info.py’
#
# info.py             100%[===================>]  22.31K  --.-KB/s    in 0s
#
# 2023-04-10 19:06:49 (98.4 MB/s) - ‘info.py’ saved [22841/22841]

# %%
# Downloads the dataset file hosted on Zenodo.
file_path = get_file(fname="dataset.npz", 
                     origin=data["url"], 
                     md5_hash=data["MD5"])
# Out:
# Downloading data from https://zenodo.org/record/6496656/files/bloodmnist.npz?download=1
# 35461855/35461855 [==============================] - 8s 0us/step

# %%
# Loads the downloaded NumPy object.
dataset = np.load(file_path)

# Gets the training images and labels from the NumPy object.
train_x = dataset["train_images"]
train_y = dataset["train_labels"]

# Gets the validation images and labels from the NumPy object.
val_x = dataset["val_images"]
val_y = dataset["val_labels"]

# Gets the testing images and labels from the NumPy object.
test_x = dataset["test_images"]
test_y = dataset["test_labels"]

# %% [markdown]
# ## Data Exploration
# having a look at our data, their distributions to see if it is ready to be used within our machine learning algorithm.

# %%
# Declares a list of labels.
labels = list(data["label"].values()) + ["total"]

# Gets the counts for each label in each of our datasets.
_, train_counts = np.unique(train_y, return_counts=True)
_, val_counts = np.unique(val_y, return_counts=True)
_, test_counts = np.unique(test_y, return_counts=True)

# Prints the counts for each label from each dataset.
print(pd.DataFrame(list(zip(np.append(train_counts, [sum(train_counts)]), 
                            np.append(val_counts, [sum(val_counts)]), 
                            np.append(test_counts, [sum(test_counts)]))), 
                   index=labels, columns=["Train", "Val", "Test"]))
# Out:
#                                                     Train   Val  Test
# basophil                                              852   122   244
# eosinophil                                           2181   312   624
# erythroblast                                         1085   155   311
# immature granulocytes(myelocytes, metamyelocyte...   2026   290   579
# lymphocyte                                            849   122   243
# monocyte                                              993   143   284
# neutrophil                                           2330   333   666
# platelet                                             1643   235   470
# total                                               11959  1712  3421

# %%
# Displays a random image from training dataset.
index = random.randint(0, len(train_x))
print(f"{index}: {labels[train_y[index][0]]}")
plt.imshow(train_x[random.randint(0, len(train_x))])
# Out:
# 1792: eosinophil

# %% [markdown]
# ## Data Processing
# We create a data loader for algorithm that will dynamiclly load and augment the data when needed.

# %%
# Defines the data generator that will be used to augment the images as they are loaded.
data_generator = ImageDataGenerator(featurewise_center=True,
                                    featurewise_std_normalization=True,
                                    horizontal_flip=True, 
                                    vertical_flip=True)

# %%
data_generator.fit(np.append(train_x, val_x, 0))

# %% [markdown]
# ## Model Definition
# define the neural network arcitecture.

# %%
# Define the input layer of the model with the size of an image.
input = layers.Input(shape=train_x[0].shape)

# Defines the first convolutional layer with max pooling.
conv_1 = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(input)
pool_1 = layers.MaxPool2D(pool_size=(2, 2))(conv_1)

# Defines the second convolutional layer with max pooling.
conv_2 = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(pool_1)
pool_2 = layers.MaxPool2D(pool_size=(2, 2))(conv_2)

# Flattens the outputs of the convolutoonal layers into a one dimensional array.
flatten = layers.Flatten()(pool_2)

# Defines the output layer of the model a number of output nodes equal to the number of classes.
output = layers.Dense(units=len(np.unique(train_y)), activation="softmax")(flatten)

# Initilises the defined model and prints summary of the model.
model = Model(inputs=input, outputs=output, name="Model")
model.summary()
# Out:
# Model: "Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 3)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 8)                 6408
#
# =================================================================
# Total params: 16,552
# Trainable params: 16,552
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model Training
# Define the training options and then train the model.

# %%
# Defines the parameters used during training.
BATCH_SIZE = 64
NUM_EPOCHS = 10
LEARNING_RATE = 0.001

# %%
# Defines the optimiser used to adjust the model weights and compiles the model.
optimiser = SGD(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimiser, loss="categorical_crossentropy", metrics=["accuracy"])

# %%
# We use the data generator to pass the training and validation data to the model to train it.
history = model.fit(data_generator.flow(train_x, to_categorical(train_y), batch_size=BATCH_SIZE), 
                    steps_per_epoch=len(train_x) / BATCH_SIZE,
                    validation_data=data_generator.flow(val_x, to_categorical(val_y), batch_size=BATCH_SIZE),
                    validation_steps=len(val_x) / BATCH_SIZE,
                    epochs=NUM_EPOCHS)
# Out:
# Epoch 1/10
# 186/186 [==============================] - 12s 15ms/step - loss: 1.9435 - accuracy: 0.2972 - val_loss: 1.8037 - val_accuracy: 0.3762
# Epoch 2/10
# 186/186 [==============================] - 2s 11ms/step - loss: 1.7121 - accuracy: 0.4121 - val_loss: 1.6257 - val_accuracy: 0.4410
# Epoch 3/10
# 186/186 [==============================] - 2s 10ms/step - loss: 1.5452 - accuracy: 0.4608 - val_loss: 1.4647 - val_accuracy: 0.5064
# Epoch 4/10
# 186/186 [==============================] - 2s 10ms/step - loss: 1.4091 - accuracy: 0.5113 - val_loss: 1.3406 - val_accuracy: 0.5304
# Epoch 5/10
# 186/186 [==============================] - 2s 10ms/step - loss: 1.2985 - accuracy: 0.5618 - val_loss: 1.2481 - val_accuracy: 0.5759
# Epoch 6/10
# 186/186 [==============================] - 2s 10ms/step - loss: 1.2151 - accuracy: 0.5939 - val_loss: 1.1703 - val_accuracy: 0.6063
# Epoch 7/10
# 186/186 [==============================] - 2s 10ms/step - loss: 1.1448 - accuracy: 0.6164 - val_loss: 1.1010 - val_accuracy: 0.6460
# Epoch 8/10
# 186/186 [==============================] - 2s 11ms/step - loss: 1.0851 - accuracy: 0.6377 - val_loss: 1.0397 - val_accuracy: 0.6653
# Epoch 9/10
# 186/186 [==============================] - 2s 10ms/step - loss: 1.0253 - accuracy: 0.6588 - val_loss: 0.9958 - val_accuracy: 0.6746
# Epoch 10/10
# 186/186 [==============================] - 2s 9ms/step - loss: 0.9786 - accuracy: 0.6740 - val_loss: 0.9385 - val_accuracy: 0.6893

# %% [markdown]
# ## Plot Learning Curves
# Visualise the training of the model.

# %%
# Plots the training and validation accuracy over the number of epochs.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
# Plots the training and validation loss over the number of epochs.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## Question 2
# Dense Layer Only

# %%
input = layers.Input(shape=train_x[0].shape)

dense_1 = layers.Dense(units=64, activation="relu")(input)
dense_2 = layers.Dense(units=64, activation="relu")(dense_1)
dense_3 = layers.Dense(units=64, activation="relu")(dense_2)

flatten = layers.Flatten()(dense_3)

output = layers.Dense(units=len(np.unique(train_y)), activation="softmax")(flatten)

model = Model(inputs=input, outputs=output, name="Model")
model.summary()
# Out:
# Model: "Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 3)]       0
#
#  dense_1 (Dense)             (None, 28, 28, 64)        256
#
#  dense_2 (Dense)             (None, 28, 28, 64)        4160
#
#  dense_3 (Dense)             (None, 28, 28, 64)        4160
#
#  flatten_1 (Flatten)         (None, 50176)             0
#
#  dense_4 (Dense)             (None, 8)                 401416
#
# =================================================================
# Total params: 409,992
# Trainable params: 409,992
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Model Training
# This is where we define the training options and then train the model.

# %%
BATCH_SIZE = 68
NUM_EPOCHS = 18
LEARNING_RATE = 0.003

# %%
optimiser = SGD(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimiser, loss="binary_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(data_generator.flow(train_x, to_categorical(train_y), batch_size=BATCH_SIZE), 
                    steps_per_epoch=len(train_x) / BATCH_SIZE,
                    validation_data=data_generator.flow(val_x, to_categorical(val_y), batch_size=BATCH_SIZE),
                    validation_steps=len(val_x) / BATCH_SIZE,
                    epochs=NUM_EPOCHS)
# Out:
# Epoch 1/18
# 175/175 [==============================] - 4s 14ms/step - loss: 0.4050 - accuracy: 0.2450 - val_loss: 0.3532 - val_accuracy: 0.3312
# Epoch 2/18
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3426 - accuracy: 0.4134 - val_loss: 0.3322 - val_accuracy: 0.4422
# Epoch 3/18
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3221 - accuracy: 0.4786 - val_loss: 0.3118 - val_accuracy: 0.4918
# Epoch 4/18
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3018 - accuracy: 0.5220 - val_loss: 0.2916 - val_accuracy: 0.5456
# Epoch 5/18
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2828 - accuracy: 0.5598 - val_loss: 0.2734 - val_accuracy: 0.5882
# Epoch 6/18
# 175/175 [==============================] - 3s 19ms/step - loss: 0.2663 - accuracy: 0.5898 - val_loss: 0.2586 - val_accuracy: 0.6098
# Epoch 7/18
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2529 - accuracy: 0.6123 - val_loss: 0.2454 - val_accuracy: 0.6303
# Epoch 8/18
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2420 - accuracy: 0.6293 - val_loss: 0.2361 - val_accuracy: 0.6373
# Epoch 9/18
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2327 - accuracy: 0.6441 - val_loss: 0.2274 - val_accuracy: 0.6513
# Epoch 10/18
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2252 - accuracy: 0.6539 - val_loss: 0.2198 - val_accuracy: 0.6641
# Epoch 11/18
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2182 - accuracy: 0.6656 - val_loss: 0.2134 - val_accuracy: 0.6711
# Epoch 12/18
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2122 - accuracy: 0.6761 - val_loss: 0.2078 - val_accuracy: 0.6840
# Epoch 13/18
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2065 - accuracy: 0.6858 - val_loss: 0.2020 - val_accuracy: 0.6974
# Epoch 14/18
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2012 - accuracy: 0.6951 - val_loss: 0.1970 - val_accuracy: 0.7009
# Epoch 15/18
# 175/175 [==============================] - 3s 17ms/step - loss: 0.1963 - accuracy: 0.7036 - val_loss: 0.1922 - val_accuracy: 0.7138
# Epoch 16/18
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1918 - accuracy: 0.7118 - val_loss: 0.1879 - val_accuracy: 0.7196
# Epoch 17/18
# 175/175 [==============================] - 3s 15ms/step - loss: 0.1877 - accuracy: 0.7194 - val_loss: 0.1840 - val_accuracy: 0.7237
# Epoch 18/18
# 175/175 [==============================] - 3s 14ms/step - loss: 0.1839 - accuracy: 0.7247 - val_loss: 0.1801 - val_accuracy: 0.7395

# %% [markdown]
# # Plot Learning Curves
# This is where we visualise the training of the model.

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## Question 3

# %% [markdown]
# ## Model Definition
# define the neural network arcitecture.

# %%
# Define the input layer of the model with the size of an image.
input = layers.Input(shape=train_x[0].shape)

# Defines the first convolutional layer with max pooling.
conv_1 = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(input)
pool_1 = layers.MaxPool2D(pool_size=(2, 2))(conv_1)

# Defines the second convolutional layer with max pooling.
conv_2 = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(pool_1)
pool_2 = layers.MaxPool2D(pool_size=(2, 2))(conv_2)

conv_3 = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(pool_2)
pool_3 = layers.MaxPool2D(pool_size=(2, 2))(conv_2)
# Defines the second convolutional layer with max pooling.
conv_4 = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(pool_3)
pool_4 = layers.MaxPool2D(pool_size=(2, 2))(conv_2)

# Flattens the outputs of the convolutoonal layers into a one dimensional array.
flatten = layers.Flatten()(pool_4)

# Defines the output layer of the model a number of output nodes equal to the number of classes.
dense_1 = layers.Dense(units=len(np.unique(train_y)), activation="relu")(flatten)
dense_2 = layers.Dense(units=len(np.unique(train_y)), activation="relu")(dense_1)
dense_3 = layers.Dense(units=len(np.unique(train_y)), activation="relu")(dense_2)
dense_4 = layers.Dense(units=len(np.unique(train_y)), activation="relu")(dense_3)

# Defines the output layer of the model a number of output nodes equal to the number of classes.
output = layers.Dense(units=len(np.unique(train_y)), activation="softmax")(dense_4)

# Initilises the defined model and prints summary of the model.
model = Model(inputs=input, outputs=output, name="Model")
model.summary()
# Out:
# Model: "Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 3)]       0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        896
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 800)               0
#
#  dense_5 (Dense)             (None, 8)                 6408
#
#  dense_6 (Dense)             (None, 8)                 72
#
#  dense_7 (Dense)             (None, 8)                 72
#
#  dense_8 (Dense)             (None, 8)                 72
#
#  dense_9 (Dense)             (None, 8)                 72
#
# =================================================================
# Total params: 16,840
# Trainable params: 16,840
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model Training
# Define the training options and then train the model.

# %%
# Defines the parameters used during training.
BATCH_SIZE = 64
NUM_EPOCHS = 10
LEARNING_RATE = 0.001

# %%
# Defines the optimiser used to adjust the model weights and compiles the model.
optimiser = SGD(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimiser, loss="categorical_crossentropy", metrics=["accuracy"])

# %%
# We use the data generator to pass the training and validation data to the model to train it.
history = model.fit(data_generator.flow(train_x, to_categorical(train_y), batch_size=BATCH_SIZE), 
                    steps_per_epoch=len(train_x) / BATCH_SIZE,
                    validation_data=data_generator.flow(val_x, to_categorical(val_y), batch_size=BATCH_SIZE),
                    validation_steps=len(val_x) / BATCH_SIZE,
                    epochs=NUM_EPOCHS)
# Out:
# Epoch 1/10
# 186/186 [==============================] - 3s 12ms/step - loss: 2.0799 - accuracy: 0.1774 - val_loss: 2.0763 - val_accuracy: 0.1822
# Epoch 2/10
# 186/186 [==============================] - 2s 11ms/step - loss: 2.0715 - accuracy: 0.1958 - val_loss: 2.0678 - val_accuracy: 0.2214
# Epoch 3/10
# 186/186 [==============================] - 3s 14ms/step - loss: 2.0630 - accuracy: 0.2458 - val_loss: 2.0594 - val_accuracy: 0.2664
# Epoch 4/10
# 186/186 [==============================] - 2s 11ms/step - loss: 2.0542 - accuracy: 0.2868 - val_loss: 2.0504 - val_accuracy: 0.2804
# Epoch 5/10
# 186/186 [==============================] - 2s 11ms/step - loss: 2.0450 - accuracy: 0.3018 - val_loss: 2.0410 - val_accuracy: 0.3084
# Epoch 6/10
# 186/186 [==============================] - 2s 11ms/step - loss: 2.0356 - accuracy: 0.3142 - val_loss: 2.0315 - val_accuracy: 0.3107
# Epoch 7/10
# 186/186 [==============================] - 2s 11ms/step - loss: 2.0256 - accuracy: 0.3214 - val_loss: 2.0213 - val_accuracy: 0.3172
# Epoch 8/10
# 186/186 [==============================] - 2s 12ms/step - loss: 2.0143 - accuracy: 0.3251 - val_loss: 2.0088 - val_accuracy: 0.3207
# Epoch 9/10
# 186/186 [==============================] - 2s 13ms/step - loss: 2.0020 - accuracy: 0.3255 - val_loss: 1.9963 - val_accuracy: 0.3248
# Epoch 10/10
# 186/186 [==============================] - 2s 11ms/step - loss: 1.9884 - accuracy: 0.3255 - val_loss: 1.9821 - val_accuracy: 0.3236

# %% [markdown]
# ## Plot Learning Curves
# Visualise the training of the model.

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
